# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities=[]

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
# IMPORT DEPENDENCIES

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
#build the base url with APIKey included
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
     # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(' ','+')
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pevek
# Processing Record 2 of Set 1 | yar-sale
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | cherskiy
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | ilulissat
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | general roca
# Processing Record 11 of Set 1 | saint-pierre
# Processing Record 12 of Set 1 | barranca
# Processing Record 13 of Set 1 | ileza
# Processing Record 14 of Set 1 | chunhuhub
# Processing Record 15 of Set 1 | khatanga
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | nikolskoye
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | waitati
# Processing Record 20 of Set 1 | bubaque
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | namatanai
# Processing Record 23 of Set 1 | okato
# Processing Record 24 of Set 1 | baie-comeau
# Processing Record 25 of Set 1 | airai
# Processing Record 26 of Set 1 | victoria
# Processing Record 27 of Set 1 | umm durman
# City not found. Skipping...
# Processing Record 28 of Set 1 | carnarvon
# Processing Record 29 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 1 | longyearbyen
# Processing Record 31 of Set 1 | te anau
# Processing Record 32 of Set 1 | port elizabeth
# Processing Record 33 of Set 1 | hobart
# Processing Record 34 of Set 1 | mar del plata
# Processing Record 35 of Set 1 | husavik
# Processing Record 36 of Set 1 | saint george
# Processing Record 37 of Set 1 | darnah
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | khawhai
# Processing Record 40 of Set 1 | barrow
# Processing Record 41 of Set 1 | thompson
# Processing Record 42 of Set 1 | nanortalik
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | tiznit
# Processing Record 46 of Set 1 | hasaki
# Processing Record 47 of Set 1 | san pedro
# Processing Record 48 of Set 1 | ribeira grande
# Processing Record 49 of Set 1 | aripuana
# Processing Record 50 of Set 1 | lalomanu
# City not found. Skipping...
# Processing Record 1 of Set 2 | padang
# Processing Record 2 of Set 2 | margate
# Processing Record 3 of Set 2 | upernavik
# Processing Record 4 of Set 2 | darovskoy
# Processing Record 5 of Set 2 | ucluelet
# Processing Record 6 of Set 2 | noumea
# Processing Record 7 of Set 2 | vila velha
# Processing Record 8 of Set 2 | huarmey
# Processing Record 9 of Set 2 | birjand
# Processing Record 10 of Set 2 | borger
# Processing Record 11 of Set 2 | havelock
# Processing Record 12 of Set 2 | clyde river
# Processing Record 13 of Set 2 | sitka
# Processing Record 14 of Set 2 | tura
# Processing Record 15 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 2 | saskylakh
# Processing Record 17 of Set 2 | georgetown
# Processing Record 18 of Set 2 | aswan
# Processing Record 19 of Set 2 | guerrero negro
# Processing Record 20 of Set 2 | petauke
# Processing Record 21 of Set 2 | butaritari
# Processing Record 22 of Set 2 | hithadhoo
# Processing Record 23 of Set 2 | shenzhen
# Processing Record 24 of Set 2 | mataura
# Processing Record 25 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 2 | hermanus
# Processing Record 27 of Set 2 | valparaiso
# Processing Record 28 of Set 2 | bambous virieux
# Processing Record 29 of Set 2 | atambua
# Processing Record 30 of Set 2 | zhanakorgan
# Processing Record 31 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 2 | saint-augustin
# Processing Record 33 of Set 2 | tiksi
# Processing Record 34 of Set 2 | dingle
# Processing Record 35 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 2 | narsaq
# Processing Record 37 of Set 2 | kalianget
# Processing Record 38 of Set 2 | belmonte
# Processing Record 39 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 2 | lerwick
# Processing Record 41 of Set 2 | lorengau
# Processing Record 42 of Set 2 | vila franca do campo
# Processing Record 43 of Set 2 | omsukchan
# Processing Record 44 of Set 2 | naze
# Processing Record 45 of Set 2 | kapaa
# Processing Record 46 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 2 | kamwenge
# Processing Record 48 of Set 2 | arraial do cabo
# Processing Record 49 of Set 2 | lucapa
# Processing Record 50 of Set 2 | castro
# Processing Record 1 of Set 3 | katherine
# Processing Record 2 of Set 3 | tupik
# Processing Record 3 of Set 3 | serenje
# Processing Record 4 of Set 3 | ponta do sol
# Processing Record 5 of Set 3 | kodiak
# Processing Record 6 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 3 | kabanjahe
# Processing Record 8 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 3 | kaitangata
# Processing Record 10 of Set 3 | tabou
# Processing Record 11 of Set 3 | tasiilaq
# Processing Record 12 of Set 3 | jiuquan
# Processing Record 13 of Set 3 | tulun
# Processing Record 14 of Set 3 | cayenne
# Processing Record 15 of Set 3 | mackay
# Processing Record 16 of Set 3 | ukiah
# Processing Record 17 of Set 3 | saint-philippe
# Processing Record 18 of Set 3 | rio grande
# Processing Record 19 of Set 3 | naryan-mar
# Processing Record 20 of Set 3 | takoradi
# Processing Record 21 of Set 3 | coihaique
# Processing Record 22 of Set 3 | gornopravdinsk
# Processing Record 23 of Set 3 | fort nelson
# Processing Record 24 of Set 3 | hamada
# Processing Record 25 of Set 3 | jacareacanga
# Processing Record 26 of Set 3 | tuatapere
# Processing Record 27 of Set 3 | bluff
# Processing Record 28 of Set 3 | mawab
# Processing Record 29 of Set 3 | kloulklubed
# Processing Record 30 of Set 3 | broken hill
# Processing Record 31 of Set 3 | mogochin
# City not found. Skipping...
# Processing Record 32 of Set 3 | kirsanov
# Processing Record 33 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 34 of Set 3 | mahebourg
# Processing Record 35 of Set 3 | ugoofaaru
# Processing Record 36 of Set 3 | yellowknife
# Processing Record 37 of Set 3 | sibu
# Processing Record 38 of Set 3 | port alfred
# Processing Record 39 of Set 3 | riyadh
# Processing Record 40 of Set 3 | abnub
# Processing Record 41 of Set 3 | sindor
# Processing Record 42 of Set 3 | kamen-rybolov
# Processing Record 43 of Set 3 | kavieng
# Processing Record 44 of Set 3 | aanekoski
# Processing Record 45 of Set 3 | xiazhen
# Processing Record 46 of Set 3 | axim
# Processing Record 47 of Set 3 | bethel
# Processing Record 48 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 3 | agirish
# Processing Record 50 of Set 3 | vaini
# Processing Record 1 of Set 4 | pontes e lacerda
# Processing Record 2 of Set 4 | vestmannaeyjar
# Processing Record 3 of Set 4 | nizhnyaya tura
# Processing Record 4 of Set 4 | chernaya kholunitsa
# Processing Record 5 of Set 4 | walvis bay
# Processing Record 6 of Set 4 | dikson
# Processing Record 7 of Set 4 | emba
# Processing Record 8 of Set 4 | hilo
# Processing Record 9 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 4 | kungurtug
# Processing Record 11 of Set 4 | coahuayana
# Processing Record 12 of Set 4 | jamestown
# Processing Record 13 of Set 4 | tekkalakota
# City not found. Skipping...
# Processing Record 14 of Set 4 | lovington
# Processing Record 15 of Set 4 | alofi
# Processing Record 16 of Set 4 | matongo
# Processing Record 17 of Set 4 | kintampo
# Processing Record 18 of Set 4 | faanui
# Processing Record 19 of Set 4 | laguna
# Processing Record 20 of Set 4 | chuy
# Processing Record 21 of Set 4 | jalu
# Processing Record 22 of Set 4 | gushikawa
# Processing Record 23 of Set 4 | vanavara
# Processing Record 24 of Set 4 | quelimane
# Processing Record 25 of Set 4 | sinnamary
# Processing Record 26 of Set 4 | avarua
# Processing Record 27 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 4 | kahului
# Processing Record 29 of Set 4 | pochutla
# Processing Record 30 of Set 4 | chifeng
# Processing Record 31 of Set 4 | bismarck
# Processing Record 32 of Set 4 | vanimo
# Processing Record 33 of Set 4 | sorland
# Processing Record 34 of Set 4 | ginda
# Processing Record 35 of Set 4 | porto novo
# Processing Record 36 of Set 4 | kashi
# Processing Record 37 of Set 4 | clarence town
# Processing Record 38 of Set 4 | ponta grossa
# Processing Record 39 of Set 4 | ahipara
# Processing Record 40 of Set 4 | namibe
# Processing Record 41 of Set 4 | sayyan
# Processing Record 42 of Set 4 | phumi samraong
# City not found. Skipping...
# Processing Record 43 of Set 4 | provideniya
# Processing Record 44 of Set 4 | guinguineo
# Processing Record 45 of Set 4 | fortuna
# Processing Record 46 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 4 | changde
# Processing Record 48 of Set 4 | bireun
# Processing Record 49 of Set 4 | xghajra
# City not found. Skipping...
# Processing Record 50 of Set 4 | sire
# Processing Record 1 of Set 5 | mocuba
# Processing Record 2 of Set 5 | usoke
# Processing Record 3 of Set 5 | villa sandino
# Processing Record 4 of Set 5 | evinayong
# Processing Record 5 of Set 5 | tyrma
# Processing Record 6 of Set 5 | artvin
# Processing Record 7 of Set 5 | acapulco
# Processing Record 8 of Set 5 | opuwo
# Processing Record 9 of Set 5 | katsuura
# Processing Record 10 of Set 5 | linping
# Processing Record 11 of Set 5 | erzin
# Processing Record 12 of Set 5 | skibbereen
# Processing Record 13 of Set 5 | norman wells
# Processing Record 14 of Set 5 | nikki
# Processing Record 15 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 16 of Set 5 | xuddur
# Processing Record 17 of Set 5 | asau
# Processing Record 18 of Set 5 | baruun-urt
# Processing Record 19 of Set 5 | cidreira
# Processing Record 20 of Set 5 | torbay
# Processing Record 21 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 22 of Set 5 | saint-francois
# Processing Record 23 of Set 5 | vao
# Processing Record 24 of Set 5 | khandyga
# Processing Record 25 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 5 | bilma
# Processing Record 27 of Set 5 | alice springs
# Processing Record 28 of Set 5 | grand gaube
# Processing Record 29 of Set 5 | stornoway
# Processing Record 30 of Set 5 | itoman
# Processing Record 31 of Set 5 | campeche
# Processing Record 32 of Set 5 | korla
# Processing Record 33 of Set 5 | benguela
# Processing Record 34 of Set 5 | mayo
# Processing Record 35 of Set 5 | kruisfontein
# Processing Record 36 of Set 5 | necochea
# Processing Record 37 of Set 5 | fairview
# Processing Record 38 of Set 5 | tapaua
# City not found. Skipping...
# Processing Record 39 of Set 5 | luderitz
# Processing Record 40 of Set 5 | pangoa
# Processing Record 41 of Set 5 | petropavlovka
# Processing Record 42 of Set 5 | savannah bight
# Processing Record 43 of Set 5 | samarai
# Processing Record 44 of Set 5 | shimanovsk
# Processing Record 45 of Set 5 | mount gambier
# Processing Record 46 of Set 5 | halifax
# Processing Record 47 of Set 5 | port-de-bouc
# Processing Record 48 of Set 5 | northam
# Processing Record 49 of Set 5 | barrhead
# Processing Record 50 of Set 5 | new norfolk
# Processing Record 1 of Set 6 | cap malheureux
# Processing Record 2 of Set 6 | tautira
# Processing Record 3 of Set 6 | fatehpur
# Processing Record 4 of Set 6 | nalut
# Processing Record 5 of Set 6 | alim
# Processing Record 6 of Set 6 | jiaojiang
# Processing Record 7 of Set 6 | bad mergentheim
# Processing Record 8 of Set 6 | geraldton
# Processing Record 9 of Set 6 | tilichiki
# Processing Record 10 of Set 6 | palmer
# Processing Record 11 of Set 6 | ambulu
# Processing Record 12 of Set 6 | ofunato
# Processing Record 13 of Set 6 | tuktoyaktuk
# Processing Record 14 of Set 6 | klyuchi
# Processing Record 15 of Set 6 | chokurdakh
# Processing Record 16 of Set 6 | yarkovo
# Processing Record 17 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 6 | bathsheba
# Processing Record 19 of Set 6 | manokwari
# Processing Record 20 of Set 6 | novoagansk
# Processing Record 21 of Set 6 | andevoranto
# City not found. Skipping...
# Processing Record 22 of Set 6 | micheweni
# Processing Record 23 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 24 of Set 6 | grindavik
# Processing Record 25 of Set 6 | sechura
# Processing Record 26 of Set 6 | lagoa
# Processing Record 27 of Set 6 | xingyi
# Processing Record 28 of Set 6 | monte carmelo
# Processing Record 29 of Set 6 | jashpurnagar
# Processing Record 30 of Set 6 | preston
# Processing Record 31 of Set 6 | lebu
# Processing Record 32 of Set 6 | harnosand
# Processing Record 33 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 34 of Set 6 | atar
# Processing Record 35 of Set 6 | port hardy
# Processing Record 36 of Set 6 | nizhniy odes
# Processing Record 37 of Set 6 | alta floresta
# Processing Record 38 of Set 6 | torquay
# Processing Record 39 of Set 6 | lodhran
# Processing Record 40 of Set 6 | homer
# Processing Record 41 of Set 6 | amga
# Processing Record 42 of Set 6 | marawi
# Processing Record 43 of Set 6 | severnoye
# Processing Record 44 of Set 6 | sterling
# Processing Record 45 of Set 6 | dubbo
# Processing Record 46 of Set 6 | oksfjord
# Processing Record 47 of Set 6 | pafos
# Processing Record 48 of Set 6 | wattegama
# Processing Record 49 of Set 6 | pemangkat
# Processing Record 50 of Set 6 | bernalda
# Processing Record 1 of Set 7 | leningradskiy
# Processing Record 2 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 3 of Set 7 | lima
# Processing Record 4 of Set 7 | haines junction
# Processing Record 5 of Set 7 | kupang
# Processing Record 6 of Set 7 | moose factory
# Processing Record 7 of Set 7 | erenhot
# Processing Record 8 of Set 7 | sanmenxia
# Processing Record 9 of Set 7 | kasongo
# Processing Record 10 of Set 7 | martinopolis
# Processing Record 11 of Set 7 | veraval
# Processing Record 12 of Set 7 | havre-saint-pierre
# Processing Record 13 of Set 7 | luancheng
# Processing Record 14 of Set 7 | inuvik
# Processing Record 15 of Set 7 | santa rosa
# Processing Record 16 of Set 7 | creel
# Processing Record 17 of Set 7 | stryn
# Processing Record 18 of Set 7 | anadyr
# Processing Record 19 of Set 7 | sokolskoye
# Processing Record 20 of Set 7 | north bend
# Processing Record 21 of Set 7 | cabedelo
# Processing Record 22 of Set 7 | kisaran
# Processing Record 23 of Set 7 | lasa
# Processing Record 24 of Set 7 | san patricio
# Processing Record 25 of Set 7 | jalingo
# Processing Record 26 of Set 7 | ullapool
# Processing Record 27 of Set 7 | severo-kurilsk
# Processing Record 28 of Set 7 | east london
# Processing Record 29 of Set 7 | mangrol
# Processing Record 30 of Set 7 | henties bay
# Processing Record 31 of Set 7 | pasighat
# Processing Record 32 of Set 7 | westport
# Processing Record 33 of Set 7 | coachella
# Processing Record 34 of Set 7 | shitanjing
# Processing Record 35 of Set 7 | nome
# Processing Record 36 of Set 7 | port hedland
# Processing Record 37 of Set 7 | leshukonskoye
# Processing Record 38 of Set 7 | shenjiamen
# Processing Record 39 of Set 7 | tukrah
# Processing Record 40 of Set 7 | barbosa ferraz
# Processing Record 41 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 42 of Set 7 | fairbanks
# Processing Record 43 of Set 7 | codrington
# Processing Record 44 of Set 7 | goderich
# Processing Record 45 of Set 7 | qasigiannguit
# Processing Record 46 of Set 7 | olafsvik
# Processing Record 47 of Set 7 | meulaboh
# Processing Record 48 of Set 7 | khormuj
# City not found. Skipping...
# Processing Record 49 of Set 7 | iwata
# Processing Record 50 of Set 7 | san lawrenz
# Processing Record 1 of Set 8 | ormara
# Processing Record 2 of Set 8 | aktash
# Processing Record 3 of Set 8 | matamoros
# Processing Record 4 of Set 8 | shimoda
# Processing Record 5 of Set 8 | vardo
# Processing Record 6 of Set 8 | ipixuna
# Processing Record 7 of Set 8 | mvuma
# Processing Record 8 of Set 8 | mukhen
# Processing Record 9 of Set 8 | okitipupa
# Processing Record 10 of Set 8 | saint anthony
# Processing Record 11 of Set 8 | san cristobal
# Processing Record 12 of Set 8 | nabire
# Processing Record 13 of Set 8 | bereda
# Processing Record 14 of Set 8 | isangel
# Processing Record 15 of Set 8 | jeremie
# Processing Record 16 of Set 8 | kampot
# Processing Record 17 of Set 8 | maarianhamina
# Processing Record 18 of Set 8 | monrovia
# Processing Record 19 of Set 8 | adrar
# Processing Record 20 of Set 8 | conceicao do araguaia
# Processing Record 21 of Set 8 | buraydah
# Processing Record 22 of Set 8 | rio gallegos
# Processing Record 23 of Set 8 | komsomolskiy
# Processing Record 24 of Set 8 | kilindoni
# Processing Record 25 of Set 8 | tank
# Processing Record 26 of Set 8 | pucara
# Processing Record 27 of Set 8 | uralskiy
# City not found. Skipping...
# Processing Record 28 of Set 8 | la ronge
# Processing Record 29 of Set 8 | zhanaozen
# Processing Record 30 of Set 8 | puerto del rosario
# Processing Record 31 of Set 8 | chara
# Processing Record 32 of Set 8 | ballina
# Processing Record 33 of Set 8 | san carlos de bariloche
# Processing Record 34 of Set 8 | severobaykalsk
# Processing Record 35 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 36 of Set 8 | bud
# Processing Record 37 of Set 8 | vesoul
# Processing Record 38 of Set 8 | taoudenni
# Processing Record 39 of Set 8 | antalaha
# Processing Record 40 of Set 8 | sangin
# Processing Record 41 of Set 8 | ostrovnoy
# Processing Record 42 of Set 8 | aykhal
# Processing Record 43 of Set 8 | wagga wagga
# Processing Record 44 of Set 8 | avera
# Processing Record 45 of Set 8 | bengkulu
# Processing Record 46 of Set 8 | jarjis
# City not found. Skipping...
# Processing Record 47 of Set 8 | arlit
# Processing Record 48 of Set 8 | makinsk
# Processing Record 49 of Set 8 | yomou
# Processing Record 50 of Set 8 | broome
# Processing Record 1 of Set 9 | saint-louis
# Processing Record 2 of Set 9 | obidos
# Processing Record 3 of Set 9 | mormugao
# Processing Record 4 of Set 9 | luga
# Processing Record 5 of Set 9 | baculin
# Processing Record 6 of Set 9 | matagami
# Processing Record 7 of Set 9 | sao filipe
# Processing Record 8 of Set 9 | shangzhi
# Processing Record 9 of Set 9 | rawson
# Processing Record 10 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 11 of Set 9 | livramento
# Processing Record 12 of Set 9 | toora-khem
# Processing Record 13 of Set 9 | bilibino
# Processing Record 14 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 9 | conde
# Processing Record 16 of Set 9 | roshni-chu
# Processing Record 17 of Set 9 | utinga
# Processing Record 18 of Set 9 | kuala terengganu
# Processing Record 19 of Set 9 | hargeysa
# Processing Record 20 of Set 9 | karlivka
# Processing Record 21 of Set 9 | mandera
# Processing Record 22 of Set 9 | chama
# Processing Record 23 of Set 9 | kamina
# Processing Record 24 of Set 9 | portree
# Processing Record 25 of Set 9 | los llanos de aridane
# Processing Record 26 of Set 9 | lompoc
# Processing Record 27 of Set 9 | lata
# Processing Record 28 of Set 9 | biak
# Processing Record 29 of Set 9 | wanning
# Processing Record 30 of Set 9 | san lorenzo
# Processing Record 31 of Set 9 | mari-turek
# Processing Record 32 of Set 9 | bejar
# Processing Record 33 of Set 9 | touros
# Processing Record 34 of Set 9 | carolina
# Processing Record 35 of Set 9 | kolondieba
# Processing Record 36 of Set 9 | balsas
# Processing Record 37 of Set 9 | deer lake
# Processing Record 38 of Set 9 | chongwe
# Processing Record 39 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 40 of Set 9 | mizan teferi
# Processing Record 41 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 9 | nara
# Processing Record 43 of Set 9 | tanggu
# Processing Record 44 of Set 9 | antofagasta
# Processing Record 45 of Set 9 | taguatinga
# Processing Record 46 of Set 9 | daru
# Processing Record 47 of Set 9 | dzilam gonzalez
# Processing Record 48 of Set 9 | montoro
# Processing Record 49 of Set 9 | hoa binh
# Processing Record 50 of Set 9 | bria
# Processing Record 1 of Set 10 | ancud
# Processing Record 2 of Set 10 | ciudad guayana
# Processing Record 3 of Set 10 | tual
# Processing Record 4 of Set 10 | mount isa
# Processing Record 5 of Set 10 | labuhan
# Processing Record 6 of Set 10 | mingshui
# Processing Record 7 of Set 10 | sibolga
# Processing Record 8 of Set 10 | aasiaat
# Processing Record 9 of Set 10 | akyab
# Processing Record 10 of Set 10 | makakilo city
# Processing Record 11 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 12 of Set 10 | deputatskiy
# Processing Record 13 of Set 10 | sal rei
# Processing Record 14 of Set 10 | zdvinsk
# Processing Record 15 of Set 10 | hamilton
# Processing Record 16 of Set 10 | khorramshahr
# Processing Record 17 of Set 10 | rocha
# Processing Record 18 of Set 10 | chapais
# Processing Record 19 of Set 10 | ushtobe
# Processing Record 20 of Set 10 | esperance
# Processing Record 21 of Set 10 | madimba
# Processing Record 22 of Set 10 | kenora
# Processing Record 23 of Set 10 | newport
# Processing Record 24 of Set 10 | marabba
# Processing Record 25 of Set 10 | kjollefjord
# Processing Record 26 of Set 10 | borisoglebskiy
# Processing Record 27 of Set 10 | phan rang
# City not found. Skipping...
# Processing Record 28 of Set 10 | manggar
# Processing Record 29 of Set 10 | salisbury
# Processing Record 30 of Set 10 | casa grande
# Processing Record 31 of Set 10 | maragogi
# Processing Record 32 of Set 10 | bhopal
# Processing Record 33 of Set 10 | souillac
# Processing Record 34 of Set 10 | pyay
# Processing Record 35 of Set 10 | martapura
# Processing Record 36 of Set 10 | bosaso
# Processing Record 37 of Set 10 | sarny
# Processing Record 38 of Set 10 | maningrida
# Processing Record 39 of Set 10 | bandar-e lengeh
# Processing Record 40 of Set 10 | nidzica
# Processing Record 41 of Set 10 | shelabolikha
# Processing Record 42 of Set 10 | salalah
# Processing Record 43 of Set 10 | labytnangi
# Processing Record 44 of Set 10 | mao
# Processing Record 45 of Set 10 | oxbow
# Processing Record 46 of Set 10 | tsienyane
# City not found. Skipping...
# Processing Record 47 of Set 10 | ketchikan
# Processing Record 48 of Set 10 | fare
# Processing Record 49 of Set 10 | puerto ayacucho
# Processing Record 50 of Set 10 | sangueya
# Processing Record 1 of Set 11 | waingapu
# Processing Record 2 of Set 11 | lichuan
# Processing Record 3 of Set 11 | port blair
# Processing Record 4 of Set 11 | lieksa
# Processing Record 5 of Set 11 | rundu
# Processing Record 6 of Set 11 | choctaw
# Processing Record 7 of Set 11 | yulara
# Processing Record 8 of Set 11 | beringovskiy
# Processing Record 9 of Set 11 | caravelas
# Processing Record 10 of Set 11 | sylacauga
# Processing Record 11 of Set 11 | flinders
# Processing Record 12 of Set 11 | iqaluit
# Processing Record 13 of Set 11 | pacatuba
# Processing Record 14 of Set 11 | hinton
# Processing Record 15 of Set 11 | aklavik
# Processing Record 16 of Set 11 | nelson
# Processing Record 17 of Set 11 | coquimbo
# Processing Record 18 of Set 11 | dakar
# Processing Record 19 of Set 11 | guilin
# Processing Record 20 of Set 11 | yatou
# Processing Record 21 of Set 11 | khani
# Processing Record 22 of Set 11 | vice
# Processing Record 23 of Set 11 | araouane
# Processing Record 24 of Set 11 | port macquarie
# Processing Record 25 of Set 11 | omboue
# Processing Record 26 of Set 11 | talnakh
# Processing Record 27 of Set 11 | narrabri
# Processing Record 28 of Set 11 | sola
# Processing Record 29 of Set 11 | shumskiy
# Processing Record 30 of Set 11 | kropotkin
# Processing Record 31 of Set 11 | pogar
# Processing Record 32 of Set 11 | egvekinot
# Processing Record 33 of Set 11 | hoyerswerda
# Processing Record 34 of Set 11 | ahome
# Processing Record 35 of Set 11 | dullewala
# Processing Record 36 of Set 11 | yumen
# Processing Record 37 of Set 11 | magnolia
# Processing Record 38 of Set 11 | rivera
# Processing Record 39 of Set 11 | kayerkan
# Processing Record 40 of Set 11 | saint-denis
# Processing Record 41 of Set 11 | shakawe
# Processing Record 42 of Set 11 | esil
# Processing Record 43 of Set 11 | port lincoln
# Processing Record 44 of Set 11 | tanout
# Processing Record 45 of Set 11 | huayucachi
# Processing Record 46 of Set 11 | pangnirtung
# Processing Record 47 of Set 11 | hualmay
# Processing Record 48 of Set 11 | garissa
# Processing Record 49 of Set 11 | vigrestad
# Processing Record 50 of Set 11 | cabo san lucas
# Processing Record 1 of Set 12 | bonthe
# Processing Record 2 of Set 12 | selfoss
# Processing Record 3 of Set 12 | ulaangom
# Processing Record 4 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 12 | hirara
# Processing Record 6 of Set 12 | teahupoo
# Processing Record 7 of Set 12 | sakakah
# Processing Record 8 of Set 12 | edmonton
# Processing Record 9 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 12 | turtkul
# City not found. Skipping...
# Processing Record 11 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 12 of Set 12 | hun
# Processing Record 13 of Set 12 | samut songkhram
# Processing Record 14 of Set 12 | domoni
# Processing Record 15 of Set 12 | faro
# Processing Record 16 of Set 12 | chengde
# Processing Record 17 of Set 12 | mungwi
# Processing Record 18 of Set 12 | casa nova
# Processing Record 19 of Set 12 | macas
# Processing Record 20 of Set 12 | pacific grove
# Processing Record 21 of Set 12 | dodge city
# Processing Record 22 of Set 12 | marevo
# Processing Record 23 of Set 12 | bambanglipuro
# Processing Record 24 of Set 12 | portland
# Processing Record 25 of Set 12 | yazman
# Processing Record 26 of Set 12 | mopti
# Processing Record 27 of Set 12 | la baule-escoublac
# Processing Record 28 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 12 | lebork
# Processing Record 30 of Set 12 | nuuk
# Processing Record 31 of Set 12 | ilinskiy
# Processing Record 32 of Set 12 | surt
# Processing Record 33 of Set 12 | verkhoyansk
# Processing Record 34 of Set 12 | umba
# Processing Record 35 of Set 12 | zhigansk
# Processing Record 36 of Set 12 | atbasar
# Processing Record 37 of Set 12 | college
# Processing Record 38 of Set 12 | almaznyy
# Processing Record 39 of Set 12 | lukulu
# Processing Record 40 of Set 12 | bontang
# Processing Record 41 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 42 of Set 12 | buloh kasap
# Processing Record 43 of Set 12 | porto santo
# Processing Record 44 of Set 12 | preobrazheniye
# Processing Record 45 of Set 12 | chino
# Processing Record 46 of Set 12 | jieshi
# Processing Record 47 of Set 12 | qandala
# Processing Record 48 of Set 12 | tampin
# Processing Record 49 of Set 12 | harper
# Processing Record 50 of Set 12 | kaluga
# Processing Record 1 of Set 13 | tiarei
# Processing Record 2 of Set 13 | burica
# City not found. Skipping...
# Processing Record 3 of Set 13 | tombouctou
# Processing Record 4 of Set 13 | virden
# Processing Record 5 of Set 13 | netishyn
# Processing Record 6 of Set 13 | kargil
# Processing Record 7 of Set 13 | parrita
# Processing Record 8 of Set 13 | kulhudhuffushi
# Processing Record 9 of Set 13 | abalak
# Processing Record 10 of Set 13 | shubarkuduk
# Processing Record 11 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 13 | sangar
# Processing Record 13 of Set 13 | tingo maria
# Processing Record 14 of Set 13 | saldanha
# Processing Record 15 of Set 13 | abu samrah
# Processing Record 16 of Set 13 | solwezi
# Processing Record 17 of Set 13 | vestmanna
# Processing Record 18 of Set 13 | sakaiminato
# Processing Record 19 of Set 13 | namie
# Processing Record 20 of Set 13 | izhma
# Processing Record 21 of Set 13 | liverpool
# Processing Record 22 of Set 13 | truth or consequences
# Processing Record 23 of Set 13 | paamiut
# Processing Record 24 of Set 13 | seoul
# Processing Record 25 of Set 13 | opunake
# Processing Record 26 of Set 13 | sidi ali
# Processing Record 27 of Set 13 | chinsali
# Processing Record 28 of Set 13 | havoysund
# Processing Record 29 of Set 13 | mossendjo
# Processing Record 30 of Set 13 | catamarca
# Processing Record 31 of Set 13 | kununurra
# Processing Record 32 of Set 13 | kyshtovka
# Processing Record 33 of Set 13 | hurricane
# Processing Record 34 of Set 13 | pyu
# Processing Record 35 of Set 13 | marystown
# Processing Record 36 of Set 13 | sulangan
# Processing Record 37 of Set 13 | xacmaz
# Processing Record 38 of Set 13 | litovko
# Processing Record 39 of Set 13 | xiaoweizhai
# Processing Record 40 of Set 13 | goiana
# Processing Record 41 of Set 13 | sioux lookout
# Processing Record 42 of Set 13 | marv dasht
# City not found. Skipping...
# Processing Record 43 of Set 13 | victor harbor
# Processing Record 44 of Set 13 | simoes
# Processing Record 45 of Set 13 | ust-karsk
# Processing Record 46 of Set 13 | dunedin
# Processing Record 47 of Set 13 | mattru
# Processing Record 48 of Set 13 | nelson bay
# Processing Record 49 of Set 13 | ulagan
# Processing Record 50 of Set 13 | russell
# Processing Record 1 of Set 14 | langarud
# Processing Record 2 of Set 14 | luena
# Processing Record 3 of Set 14 | kamaishi
# Processing Record 4 of Set 14 | terney
# Processing Record 5 of Set 14 | kinsale
# Processing Record 6 of Set 14 | siderno
# Processing Record 7 of Set 14 | dien bien
# City not found. Skipping...
# Processing Record 8 of Set 14 | kaeo
# Processing Record 9 of Set 14 | gravelbourg
# Processing Record 10 of Set 14 | vostok
# Processing Record 11 of Set 14 | hantsport
# Processing Record 12 of Set 14 | joshimath
# Processing Record 13 of Set 14 | reyes
# Processing Record 14 of Set 14 | tieling
# Processing Record 15 of Set 14 | maniitsoq
# Processing Record 16 of Set 14 | kathmandu
# Processing Record 17 of Set 14 | riesi
# Processing Record 18 of Set 14 | banjar
# Processing Record 19 of Set 14 | saint-michel-des-saints
# Processing Record 20 of Set 14 | uglovskoye
# Processing Record 21 of Set 14 | camapua
# Processing Record 22 of Set 14 | daman
# Processing Record 23 of Set 14 | yining
# Processing Record 24 of Set 14 | angra
# City not found. Skipping...
# Processing Record 25 of Set 14 | puno
# Processing Record 26 of Set 14 | boguchany
# Processing Record 27 of Set 14 | aurangabad
# Processing Record 28 of Set 14 | lavrentiya
# Processing Record 29 of Set 14 | malaryta
# Processing Record 30 of Set 14 | sri aman
# Processing Record 31 of Set 14 | hami
# Processing Record 32 of Set 14 | libertador general san martin
# Processing Record 33 of Set 14 | muriwai beach
# Processing Record 34 of Set 14 | miyako
# Processing Record 35 of Set 14 | salym
# Processing Record 36 of Set 14 | brownsville
# Processing Record 37 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 38 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 39 of Set 14 | laranjeiras do sul
# Processing Record 40 of Set 14 | orocue
# Processing Record 41 of Set 14 | havre
# Processing Record 42 of Set 14 | kasane
# Processing Record 43 of Set 14 | keelung
# Processing Record 44 of Set 14 | plettenberg bay
# Processing Record 45 of Set 14 | palmas bellas
# Processing Record 46 of Set 14 | port-gentil
# Processing Record 47 of Set 14 | starobaltachevo
# Processing Record 48 of Set 14 | baykit
# Processing Record 49 of Set 14 | damnagar
# Processing Record 50 of Set 14 | baghmara
# Processing Record 1 of Set 15 | one hundred mile house
# City not found. Skipping...
# Processing Record 2 of Set 15 | luba
# Processing Record 3 of Set 15 | madang
# Processing Record 4 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 5 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 6 of Set 15 | ingham
# Processing Record 7 of Set 15 | nicoya
# Processing Record 8 of Set 15 | raudeberg
# Processing Record 9 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 10 of Set 15 | bonfim
# Processing Record 11 of Set 15 | taltal
# Processing Record 12 of Set 15 | klaksvik
# Processing Record 13 of Set 15 | jining
# Processing Record 14 of Set 15 | dodoma
# Processing Record 15 of Set 15 | druzhba
# Processing Record 16 of Set 15 | little current
# Processing Record 17 of Set 15 | tzucacab
# Processing Record 18 of Set 15 | houma
# Processing Record 19 of Set 15 | vila do maio
# Processing Record 20 of Set 15 | merauke
# Processing Record 21 of Set 15 | huilong
# Processing Record 22 of Set 15 | rurrenabaque
# Processing Record 23 of Set 15 | siverek
# Processing Record 24 of Set 15 | liusha
# Processing Record 25 of Set 15 | arman
# Processing Record 26 of Set 15 | zachagansk
# City not found. Skipping...
# Processing Record 27 of Set 15 | mareeba
# Processing Record 28 of Set 15 | tocopilla
# Processing Record 29 of Set 15 | qiongshan
# Processing Record 30 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 31 of Set 15 | viedma
# Processing Record 32 of Set 15 | srednekolymsk
# Processing Record 33 of Set 15 | ios
# Processing Record 34 of Set 15 | mbandaka
# Processing Record 35 of Set 15 | morshansk
# Processing Record 36 of Set 15 | melilla
# Processing Record 37 of Set 15 | latacunga
# Processing Record 38 of Set 15 | malumfashi
# Processing Record 39 of Set 15 | moron
# Processing Record 40 of Set 15 | bridlington
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Pevek  69.7008  170.3133     12.63        91         100
# 1      Yar-Sale  66.8333   70.8333     28.80        92         100
# 2    Bredasdorp -34.5322   20.0403     63.72        88         100
# 3      Cherskiy  68.7500  161.3000      6.98        96         100
# 4  Puerto Ayora  -0.7393  -90.3518     76.96        81          64
#
#    Wind Speed      Description
# 0       13.42       light snow
# 1        6.64  overcast clouds
# 2        6.91  overcast clouds
# 3        4.45  overcast clouds
# 4        9.44    broken clouds

# %%
#######################
# Save the data to a CSV
#######################

# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
