# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities=[]

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 605

# %%
cities
# Out:
# ['nikolskoye',
#  'kavaratti',
#  'sao joao da barra',
#  'samusu',
#  'odweyne',
#  'jamestown',
#  'lagoa',
#  'calvinia',
#  'barawe',
#  'lebu',
#  'atuona',
#  'mahebourg',
#  'amapa',
#  'hermanus',
#  'beringovskiy',
#  'ushuaia',
#  'tuktoyaktuk',
#  'bluff',
#  'moron',
#  'punta arenas',
#  'kracheh',
#  'grimshaw',
#  'torbay',
#  'illoqqortoormiut',
#  'ardahan',
#  'port alfred',
#  'qasigiannguit',
#  'maniitsoq',
#  'east london',
#  'rapid valley',
#  'maceio',
#  'shiroishi',
#  'vila franca do campo',
#  'georgetown',
#  'tumannyy',
#  'elkton',
#  'khatanga',
#  'bredasdorp',
#  'carnarvon',
#  'vaini',
#  'provideniya',
#  'ranong',
#  'toamasina',
#  'fort saint john',
#  'taoudenni',
#  'busselton',
#  'avarua',
#  'trincomalee',
#  'rikitea',
#  'umm kaddadah',
#  'hobart',
#  'chokurdakh',
#  'yellowknife',
#  'port lincoln',
#  'albany',
#  'bur gabo',
#  'taolanaro',
#  'cape town',
#  'salekhard',
#  'port elizabeth',
#  'attawapiskat',
#  'samarai',
# ...

# %%
#############################

# %%
#############################
#get all data from the weather.com API for all the above cities
#############################

# %%
#############################

# %%
# IMPORT DEPENDENCIES

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
#build the base url with APIKey included
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
     # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(' ','+')
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nikolskoye
# Processing Record 2 of Set 1 | kavaratti
# Processing Record 3 of Set 1 | sao joao da barra
# Processing Record 4 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 1 | odweyne
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | lagoa
# Processing Record 8 of Set 1 | calvinia
# Processing Record 9 of Set 1 | barawe
# City not found. Skipping...
# Processing Record 10 of Set 1 | lebu
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | mahebourg
# Processing Record 13 of Set 1 | amapa
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | beringovskiy
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | tuktoyaktuk
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | moron
# Processing Record 20 of Set 1 | punta arenas
# ...

# %%
#############################

# %%
#############################
#6.2.7
#Create a DataFrame of City Weather Data
#############################

# %%
#############################

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Nikolskoye  59.7035   30.7861     32.88        80          96
# 1          Kavaratti  10.5669   72.6420     81.99        74         100
# 2  Sao Joao Da Barra -21.6403  -41.0511     71.69        89         100
# 3            Odweyne   9.4092   45.0640     76.86        43          14
# 4          Jamestown  42.0970  -79.2353     67.51        50           1
# 5              Lagoa  39.0500  -27.9833     68.29        70           2
# 6           Calvinia -31.4707   19.7760     66.74         7           0
# 7               Lebu -37.6167  -73.6500     60.03        73           2
# 8             Atuona  -9.8000 -139.0333     78.33        75           1
# 9          Mahebourg -20.4081   57.7000     73.69        78          40
#
#    Wind Speed Country                 Date
# 0        3.56      RU  2021-10-19 19:09:47
# 1        9.01      IN  2021-10-19 19:10:32
# 2       17.36      BR  2021-10-19 19:10:32
# ...

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %%
#Next, we'll reorder the columns as City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, and Wind Speed
neworder1=['City','Country','Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed']
city_data_df=city_data_df[neworder1]
city_data_df.head()
# Out:
#                 City Country                 Date      Lat      Lng  Max Temp  \
# 0         Nikolskoye      RU  2021-10-19 19:09:47  59.7035  30.7861     32.88
# 1          Kavaratti      IN  2021-10-19 19:10:32  10.5669  72.6420     81.99
# 2  Sao Joao Da Barra      BR  2021-10-19 19:10:32 -21.6403 -41.0511     71.69
# 3            Odweyne      SO  2021-10-19 19:10:33   9.4092  45.0640     76.86
# 4          Jamestown      US  2021-10-19 19:05:54  42.0970 -79.2353     67.51
#
#    Humidity  Cloudiness  Wind Speed
# 0        80          96        3.56
# 1        74         100        9.01
# 2        89         100       17.36
# 3        43          14       11.18
# 4        50           1        5.99

# %%
#######################
# Save the data to a CSV
#######################

# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
############################

# %%
############################
# CREATE SCATTER PLOTS FOR ALL THE DATA YOU JUST COLLLECTED
############################

# %%
############################

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
############################
# 6.3.1
# Plot Latitude vs. Temperature
############################

# %%
import time
time.strftime("%x")
# Out:
# '10/19/21'

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x")) #see above one cell
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# The balance of the scatter plots will share the same format. 
# All we need to do is change the y-axis variable for each weather parameter. 
# Let's create the scatter plots quickly by copying the code and changing the y-axis variable.

# %%
############################
# 6.3.2
# Plot Latitude vs. Humidity
############################

# %%
# Build the scatter plot for latitude vs. humidity
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity"+ time.strftime("%x")) #see above one cell
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig2.png")

# Show plot.
plt.show()

# %%
############################
# 6.3.3
# Plot Latitude vs. Cloudiness
############################

# %%
# Build the scatter plot for latitude vs. cloudiness
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness"+ time.strftime("%x")) #see above one cell
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig3.png")

# Show plot.
plt.show()

# %%
############################
# 6.3.4
# Plot Latitude vs. Wind Speed
############################

# %%
# Build the scatter plot for latitude vs. Wind Speed
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed"+ time.strftime("%x")) #see above one cell
plt.ylabel("Wind SPeed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig4.png")

# Show plot.
plt.show()

# %%
city_data_df.head()
# Out:
#                 City Country                 Date      Lat      Lng  Max Temp  \
# 0         Nikolskoye      RU  2021-10-19 19:09:47  59.7035  30.7861     32.88
# 1          Kavaratti      IN  2021-10-19 19:10:32  10.5669  72.6420     81.99
# 2  Sao Joao Da Barra      BR  2021-10-19 19:10:32 -21.6403 -41.0511     71.69
# 3            Odweyne      SO  2021-10-19 19:10:33   9.4092  45.0640     76.86
# 4          Jamestown      US  2021-10-19 19:05:54  42.0970 -79.2353     67.51
#
#    Humidity  Cloudiness  Wind Speed
# 0        80          96        3.56
# 1        74         100        9.01
# 2        89         100       17.36
# 3        43          14       11.18
# 4        50           1        5.99

# %%
############################
# 6.4.2
# Find the Correlation Between Latitude and Maximum Temperature
############################

# %%
# First, set up a function called plot_linear_regression for yourself, so you can plug in variables later
## and not have to re-type so much (...i guess(???))


# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
# Create the Hemisphere DataFrames

north_hemi = city_data_df.loc[(city_data_df['Lat']>=0)]
# north_hemi.head()
south_hemi=city_data_df.loc[(city_data_df['Lat']<=0)]
south_hemi.head()
# Out:
#                 City Country                 Date      Lat       Lng  \
# 2  Sao Joao Da Barra      BR  2021-10-19 19:10:32 -21.6403  -41.0511
# 6           Calvinia      ZA  2021-10-19 19:10:33 -31.4707   19.7760
# 7               Lebu      CL  2021-10-19 19:09:45 -37.6167  -73.6500
# 8             Atuona      PF  2021-10-19 19:09:40  -9.8000 -139.0333
# 9          Mahebourg      MU  2021-10-19 19:09:57 -20.4081   57.7000
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 2     71.69        89         100       17.36
# 6     66.74         7           0        7.07
# 7     60.03        73           2       10.33
# 8     78.33        75           1       20.49
# 9     73.69        78          40        8.05

# %%
# Linear regression on the Northern Hemisphere
x_values = north_hemi["Lat"]
y_values = north_hemi["Max Temp"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,0))

# %%
# Linear regression on the SOUTHERN Hemisphere
x_values = south_hemi["Lat"]
y_values = south_hemi["Max Temp"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
############################
# 6.4.3
# Find the Correlation Between Latitude and Percent Humidity
############################

# %%
# Linear regression on the Northern Hemisphere
x_values = north_hemi["Lat"]
y_values = north_hemi["Humidity"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Humidity', 'Humidity',(45,15))

# %%
# Linear regression on the SOUTHERN Hemisphere
x_values = south_hemi["Lat"]
y_values = south_hemi["Humidity"]

# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Humidity', 'Humidity',(-20,15))

# %%
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
print (slope, intercept, r_value, p_value, std_err)
# Out:
# 0.3193515404959513 77.9311378966552 0.22514533592168678 0.003970200004406932 0.10925718349721546
