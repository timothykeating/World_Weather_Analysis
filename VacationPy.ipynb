# %%
#######################################

# %%
#######################################
### 6.5.2
### Create Heatmaps for Weather Parameters
#######################################

# %%
#######################################

# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests

# Import the API key.
from config import g_key

# %%
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID               City Country                 Date      Lat      Lng  \
# 0        0         Nikolskoye      RU  2021-10-19 19:09:47  59.7035  30.7861
# 1        1          Kavaratti      IN  2021-10-19 19:10:32  10.5669  72.6420
# 2        2  Sao Joao Da Barra      BR  2021-10-19 19:10:32 -21.6403 -41.0511
# 3        3            Odweyne      SO  2021-10-19 19:10:33   9.4092  45.0640
# 4        4          Jamestown      US  2021-10-19 19:05:54  42.0970 -79.2353
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     32.88        80          96        3.56
# 1     81.99        74         100        9.01
# 2     71.69        89         100       17.36
# 3     76.86        43          14       11.18
# 4     67.51        50           1        5.99

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
lowtemp = city_data_df.loc[city_data_df['Max Temp']<=0]
lowtemp
# Out:
#      City_ID         City Country                 Date      Lat       Lng  \
# 45        45   Chokurdakh      RU  2021-10-19 19:09:35  70.6333  147.9167
# 103      103       Talaya      RU  2021-10-19 19:10:55  61.3833  152.7500
# 150      150  Belaya Gora      RU  2021-10-19 19:11:09  68.5333  146.4167
# 340      340     Ust-Nera      RU  2021-10-19 19:09:46  64.5667  143.2000
# 380      380     Zyryanka      RU  2021-10-19 19:12:12  65.7500  150.8500
# 436      436  Deputatskiy      RU  2021-10-19 19:09:12  69.3000  139.9000
# 514      514    Ust-Kuyga      RU  2021-10-19 19:12:51  70.0167  135.6000
# 543      543     Cherskiy      RU  2021-10-19 19:09:43  68.7500  161.3000
# 548      548        Dukat      RU  2021-10-19 19:13:00  62.5500  155.5500
#
#      Max Temp  Humidity  Cloudiness  Wind Speed
# 45      -7.22        96         100        6.64
# 103    -15.18        99          76        2.06
# 150    -10.21        99          76        4.56
# ...

# %%
# replace negative max temps with 0
max_temp=city_data_df['Max Temp']

temps=[]

for temp in max_temp:
    temps.append(max(temp,0))
temps


### In the for loop, we're using the max() function to get the largest value between the temp and 0. 
### If the temp is less than 0, then 0 will be added to the list in its place. 
### Otherwise, the temp is added to the list.
# Out:
# [32.88,
#  81.99,
#  71.69,
#  76.86,
#  67.51,
#  68.29,
#  66.74,
#  60.03,
#  78.33,
#  73.69,
#  96.26,
#  58.8,
#  26.74,
#  56.82,
#  22.35,
#  47.77,
#  78.03,
#  66.31,
#  38.01,
#  60.49,
#  38.32,
#  60.51,
#  39.45,
#  35.55,
#  61.25,
#  48.33,
#  85.44,
#  54.48,
#  70.21,
#  78.89,
#  72.36,
#  30.29,
#  58.28,
#  64.47,
#  75.36,
#  32.04,
#  77.31,
#  71.4,
#  87.03,
#  53.1,
#  75.25,
#  80.06,
#  74.93,
#  90.75,
#  40.05,
#  0,
#  45.41,
#  62.04,
#  64.94,
#  64.35,
#  32.47,
#  63.1,
#  80.94,
#  27.28,
#  40.37,
#  78.24,
#  87.24,
#  73.8,
#  39.7,
#  64.72,
#  35.56,
#  40.08,
#  42.75,
#  70.83,
#  71.91,
#  64.92,
#  72.66,
#  28.87,
#  79.72,
#  41.52,
#  48.0,
#  30.69,
#  77.72,
#  83.1,
#  49.37,
#  73.78,
#  81.54,
#  10.13,
#  81.45,
#  85.37,
#  78.76,
#  82.17,
#  74.43,
#  64.74,
#  56.5,
#  69.64,
#  66.72,
#  82.87,
#  30.34,
#  81.36,
#  48.29,
#  61.48,
#  48.85,
#  72.88,
#  43.52,
#  79.9,
#  54.28,
#  44.37,
#  79.07,
#  43.18,
#  82.17,
# ...

# %%
# 1. Assign the locations to an array of latitude and longitude pairs.
locations = city_data_df[['Lat','Lng']]


# 2. Assign the weights variable to some values.
### we assigned the weights variable as temps one cell above
### you cant have negative weights in this method, so using city_data_df['Max Temp'] will not work


# 3. Assign the figure variable to the gmaps.figure() attribute.
### use center= to center the map, 
### use zoom to zoom in to where you only see how much you want
fig = gmaps.figure(center=(30.0,31.0),zoom_level=1.85)


# 4. Assign the heatmap_layer variable to the heatmap_layer attribute and add in the locations.
### use temps, lowercase, new object created above, for the weights
### dissipating, max_intensity and point_radius are all params that help show the colors better on the heatmap
heatmap_layer = gmaps.heatmap_layer(locations, weights=temps, dissipating=False, max_intensity=300, point_radius=4)


# 5. Add the heatmap layer.
fig.add_layer(heatmap_layer)


# 6. Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#######################################
### Create a Percent Humidity Heatmap
#######################################

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]

fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#######################################
### Create a Cloudiness Heatmap
#######################################

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]

fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#######################################
### Create a Wind Speed Heatmap
#######################################

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
windspeed = city_data_df["Wind Speed"]

fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

heat_layer = gmaps.heatmap_layer(locations, weights=windspeed, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
